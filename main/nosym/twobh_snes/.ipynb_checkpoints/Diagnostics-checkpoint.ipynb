# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os
sys.path.append(os.path.abspath("../../"))    # Calling the HorizonFinder.py source code from src
from src.HorizonFinder import axisym

# %%
# Load data
data = pd.read_csv("./data/horizon_common.csv")
theta = data["theta"].values
h = data["h"].values

# %%
# Plot the surface profile
plt.plot(theta, h)
plt.xlabel(r"$\theta$")
plt.ylabel(r"$h(\theta)$")
plt.title("Apparent Horizon shape")
plt.show()

# %%
# Suppose your class instance is called `solver`
Residual = axisym.Horizon(h, theta, dtheta=theta[1] - theta[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Suppose your class instance is called `solver`
# ----> 2 Residual = axisym.Horizon(h, theta, dtheta=theta[1] - theta[0])
#
# TypeError: axisym.Horizon() missing 1 required positional argument: 'theta'
